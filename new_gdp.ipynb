# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
gdp_df = pd.read_csv("data/gdp_percapita.csv")
gdp_df
# Out:
#      Country or Area                                      Year         Value  \
# 0        Afghanistan                                      2017   1758.465636
# 1        Afghanistan                                      2016   1757.023490
# 2        Afghanistan                                      2015   1766.593077
# 3        Afghanistan                                      2014   1795.735834
# 4        Afghanistan                                      2013   1807.762344
# 5        Afghanistan                                      2012   1772.764974
# 6        Afghanistan                                      2011   1626.764793
# 7        Afghanistan                                      2010   1671.581238
# 8        Afghanistan                                      2009   1502.354073
# 9        Afghanistan                                      2008   1267.644939
# 10       Afghanistan                                      2007   1247.753118
# ...

# %%
gdp_df.head(5)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2017  1758.465636              NaN
# 1     Afghanistan  2016  1757.023490              NaN
# 2     Afghanistan  2015  1766.593077              NaN
# 3     Afghanistan  2014  1795.735834              NaN
# 4     Afghanistan  2013  1807.762344              NaN

# %%
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2017  1758.465636              NaN
# 1     Afghanistan  2016  1757.023490              NaN
# 2     Afghanistan  2015  1766.593077              NaN
# 3     Afghanistan  2014  1795.735834              NaN
# 4     Afghanistan  2013  1807.762344              NaN
# 5     Afghanistan  2012  1772.764974              NaN

# %%
internet_df = pd.read_csv("data/internet_use.csv", nrows=4495)

# %%
internet_df.head(5)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN

# %%
internet_df.shape
# Out:
# (4495, 4)

# %%
gdp_df.shape
# Out:
# (6502, 4)

# %%
internet_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4495 entries, 0 to 4494
# Data columns (total 4 columns):
# Country or Area    4495 non-null object
# Year               4495 non-null int64
# Value              4495 non-null float64
# Value Footnotes    948 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 140.5+ KB

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6502 entries, 0 to 6501
# Data columns (total 4 columns):
# Country or Area    6502 non-null object
# Year               6502 non-null object
# Value              6500 non-null float64
# Value Footnotes    1 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 203.3+ KB

# %%
internet_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
internet_df = internet_df.drop(columns=['Value Footnotes'])
internet_df.head()
# Out:
#   Country or Area  Year     Value
# 0     Afghanistan  2014  6.390000
# 1     Afghanistan  2013  5.900000
# 2     Afghanistan  2012  5.454545
# 3     Afghanistan  2011  5.000000
# 4     Afghanistan  2010  4.000000

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
gdp_df = gdp_df.drop(columns=['Value Footnotes'])
gdp_df.head()
# Out:
#   Country or Area  Year        Value
# 0     Afghanistan  2017  1758.465636
# 1     Afghanistan  2016  1757.023490
# 2     Afghanistan  2015  1766.593077
# 3     Afghanistan  2014  1795.735834
# 4     Afghanistan  2013  1807.762344

# %%
gdp_df = gdp_df.rename(columns = {'Country or Area':'Country','Year':'Year','Value':'GDP_Per_Capita'})
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2017     1758.465636
# 1  Afghanistan  2016     1757.023490
# 2  Afghanistan  2015     1766.593077
# 3  Afghanistan  2014     1795.735834
# 4  Afghanistan  2013     1807.762344

# %%
internet_df = internet_df.rename(columns = {'Country or Area':'Country','Year':'Year','Value':'Internet_Users_Pct'})
internet_df.head()
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014            6.390000
# 1  Afghanistan  2013            5.900000
# 2  Afghanistan  2012            5.454545
# 3  Afghanistan  2011            5.000000
# 4  Afghanistan  2010            4.000000

# %%
gdp_and_internet_use = pd.concat([gdp_df,internet_df])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
gdp_and_internet_use.tail()
# Out:
#        Country  GDP_Per_Capita  Internet_Users_Pct  Year
# 4490  Zimbabwe             NaN            0.033080  1997
# 4491  Zimbabwe             NaN            0.016790  1996
# 4492  Zimbabwe             NaN            0.007684  1995
# 4493  Zimbabwe             NaN            0.001739  1994
# 4494  Zimbabwe             NaN            0.000000  1990

# %%
internet_2004=gdp_and_internet_use[gdp_and_internet_use['Year'].isin ([2004])]
internet_2004
# Out:
#                      Country  GDP_Per_Capita  Internet_Users_Pct  Year
# 10               Afghanistan             NaN            0.105809  2004
# 25                   Albania             NaN            2.420388  2004
# 46                   Algeria             NaN            4.634475  2004
# 69                   Andorra             NaN           26.837954  2004
# 88                    Angola             NaN            0.464815  2004
# 108      Antigua and Barbuda             NaN           24.266544  2004
# 129                Argentina             NaN           16.036684  2004
# 153                  Armenia             NaN            4.899009  2004
# 175                    Aruba             NaN           23.000000  2004
# 215                  Austria             NaN           54.280000  2004
# 260                  Bahamas             NaN           22.000000  2004
# 281                  Bahrain             NaN           21.458681  2004
# ...

# %%
internet_2009=gdp_and_internet_use[gdp_and_internet_use['Year'].isin ([2009])]
internet_2009
# Out:
#                      Country  GDP_Per_Capita  Internet_Users_Pct  Year
# 5                Afghanistan             NaN            3.550000  2009
# 20                   Albania             NaN           41.200000  2009
# 41                   Algeria             NaN           11.230000  2009
# 64                   Andorra             NaN           78.530000  2009
# 83                    Angola             NaN            6.000000  2009
# 103      Antigua and Barbuda             NaN           42.000000  2009
# 124                Argentina             NaN           34.000000  2009
# 148                  Armenia             NaN           15.300000  2009
# 170                    Aruba             NaN           58.000000  2009
# 188                Australia             NaN           74.250000  2009
# 210                  Austria             NaN           73.450000  2009
# 235               Azerbaijan             NaN           27.400000  2009
# ...

# %%
internet_2014=gdp_and_internet_use[gdp_and_internet_use['Year'].isin ([2014])]
internet_2014
# Out:
#                      Country  GDP_Per_Capita  Internet_Users_Pct  Year
# 0                Afghanistan             NaN             6.39000  2014
# 15                   Albania             NaN            60.10000  2014
# 36                   Algeria             NaN            18.09000  2014
# 59                   Andorra             NaN            95.90000  2014
# 78                    Angola             NaN            21.26000  2014
# 98       Antigua and Barbuda             NaN            64.00000  2014
# 119                Argentina             NaN            64.70000  2014
# 143                  Armenia             NaN            46.30000  2014
# 165                    Aruba             NaN            83.78000  2014
# 183                Australia             NaN            84.56000  2014
# 205                  Austria             NaN            81.00000  2014
# 230               Azerbaijan             NaN            61.00000  2014
# ...

# %%
internet_2014
