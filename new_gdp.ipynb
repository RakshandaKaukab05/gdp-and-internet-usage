# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


# %matplotlib inline

# %%
gdp_df = pd.read_csv("data/gdp_percapita.csv",nrows=6205)
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2017  1758.465636              NaN
# 1     Afghanistan  2016  1757.023490              NaN
# 2     Afghanistan  2015  1766.593077              NaN
# 3     Afghanistan  2014  1795.735834              NaN
# 4     Afghanistan  2013  1807.762344              NaN

# %%
gdp_df.head(5)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2017  1758.465636              NaN
# 1     Afghanistan  2016  1757.023490              NaN
# 2     Afghanistan  2015  1766.593077              NaN
# 3     Afghanistan  2014  1795.735834              NaN
# 4     Afghanistan  2013  1807.762344              NaN

# %%
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2017  1758.465636              NaN
# 1     Afghanistan  2016  1757.023490              NaN
# 2     Afghanistan  2015  1766.593077              NaN
# 3     Afghanistan  2014  1795.735834              NaN
# 4     Afghanistan  2013  1807.762344              NaN
# 5     Afghanistan  2012  1772.764974              NaN

# %%
internet_df = pd.read_csv("data/internet_use.csv", nrows=4495)

# %%
internet_df.head(5)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN

# %%
internet_df.shape
# Out:
# (4495, 4)

# %%
gdp_df.shape
# Out:
# (6205, 4)

# %%
internet_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4495 entries, 0 to 4494
# Data columns (total 4 columns):
# Country or Area    4495 non-null object
# Year               4495 non-null int64
# Value              4495 non-null float64
# Value Footnotes    948 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 140.5+ KB

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6205 entries, 0 to 6204
# Data columns (total 4 columns):
# Country or Area    6205 non-null object
# Year               6205 non-null int64
# Value              6205 non-null float64
# Value Footnotes    1 non-null float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 194.0+ KB

# %%
internet_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
internet_df = internet_df.drop(columns=['Value Footnotes'])
internet_df.head()
# Out:
#   Country or Area  Year     Value
# 0     Afghanistan  2014  6.390000
# 1     Afghanistan  2013  5.900000
# 2     Afghanistan  2012  5.454545
# 3     Afghanistan  2011  5.000000
# 4     Afghanistan  2010  4.000000

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
gdp_df = gdp_df.drop(columns=['Value Footnotes'])
gdp_df.head()
# Out:
#   Country or Area  Year        Value
# 0     Afghanistan  2017  1758.465636
# 1     Afghanistan  2016  1757.023490
# 2     Afghanistan  2015  1766.593077
# 3     Afghanistan  2014  1795.735834
# 4     Afghanistan  2013  1807.762344

# %%
gdp_df = gdp_df.rename(columns = {'Country or Area':'Country','Year':'Year','Value':'GDP_Per_Capita'})
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2017     1758.465636
# 1  Afghanistan  2016     1757.023490
# 2  Afghanistan  2015     1766.593077
# 3  Afghanistan  2014     1795.735834
# 4  Afghanistan  2013     1807.762344

# %%
internet_df = internet_df.rename(columns = {'Country or Area':'Country','Year':'Year','Value':'Internet_Users_Pct'})
internet_df.head()
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014            6.390000
# 1  Afghanistan  2013            5.900000
# 2  Afghanistan  2012            5.454545
# 3  Afghanistan  2011            5.000000
# 4  Afghanistan  2010            4.000000

# %%
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2017     1758.465636
# 1  Afghanistan  2016     1757.023490
# 2  Afghanistan  2015     1766.593077
# 3  Afghanistan  2014     1795.735834
# 4  Afghanistan  2013     1807.762344

# %%
internet_df.head()
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014            6.390000
# 1  Afghanistan  2013            5.900000
# 2  Afghanistan  2012            5.454545
# 3  Afghanistan  2011            5.000000
# 4  Afghanistan  2010            4.000000

# %%
gdp_df.dtypes
# Out:
# Country            object
# Year                int64
# GDP_Per_Capita    float64
# dtype: object

# %%
internet_df.dtypes
# Out:
# Country                object
# Year                    int64
# Internet_Users_Pct    float64
# dtype: object

# %%
#gdp_df.Year=gdp_df.Year.astype(str).astype(int)

# %%
gdp_and_internet_use = pd.merge(gdp_df, internet_df, on= ['Country','Year'], how = 'inner')

# %%
gdp_and_internet_use.head()
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2014     1795.735834            6.390000
# 1  Afghanistan  2013     1807.762344            5.900000
# 2  Afghanistan  2012     1772.764974            5.454545
# 3  Afghanistan  2011     1626.764793            5.000000
# 4  Afghanistan  2010     1671.581238            4.000000

# %%
gdp_and_internet_use.tail()
# Out:
#             Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3363  United States  1994    38603.651201            4.862781
# 3364  United States  1993    37566.468232            2.271673
# 3365  United States  1992    37045.330120            1.724203
# 3366  United States  1991    36284.582233            1.163194
# 3367  United States  1990    36812.545745            0.784729

# %%
##Created the subset for 2004,2009,2014
internet_gdp=gdp_and_internet_use[gdp_and_internet_use['Year'].isin ([2004,2009,2014])]
internet_gdp
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0              Afghanistan  2014     1795.735834            6.390000
# 5              Afghanistan  2009     1502.354073            3.550000
# 10             Afghanistan  2004     1025.208245            0.105809
# 13                 Albania  2014    10700.522802           60.100000
# 18                 Albania  2009     9525.372374           41.200000
# 23                 Albania  2004     7001.054941            2.420388
# 34                 Algeria  2014    13549.025150           18.090000
# 39                 Algeria  2009    12694.745562           11.230000
# 44                 Algeria  2004    11847.319747            4.634475
# 56                  Angola  2014     6813.052106           21.260000
# 61                  Angola  2009     6292.534856            6.000000
# 66                  Angola  2004     4604.657044            0.464815
# 76     Antigua and Barbuda  2014    20820.551057           64.000000
# ...

# %%
##create a new df for year 2004

df_2004=internet_gdp[internet_gdp['Year'].isin (['2004'])]
df_2004.head()
# Out:
#                 Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 10          Afghanistan  2004     1025.208245            0.105809
# 23              Albania  2004     7001.054941            2.420388
# 44              Algeria  2004    11847.319747            4.634475
# 66               Angola  2004     4604.657044            0.464815
# 86  Antigua and Barbuda  2004    21183.426857           24.266544

# %%
##create a new df for 2009
df_2009=internet_gdp[internet_gdp['Year'].isin (['2009'])]
df_2009.head()
# Out:
#                 Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5           Afghanistan  2009     1502.354073                3.55
# 18              Albania  2009     9525.372374               41.20
# 39              Algeria  2009    12694.745562               11.23
# 61               Angola  2009     6292.534856                6.00
# 81  Antigua and Barbuda  2009    22592.413330               42.00

# %%
df_2014=internet_gdp[internet_gdp['Year'].isin (['2014'])]
df_2014.head()
# Out:
#                 Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0           Afghanistan  2014     1795.735834                6.39
# 13              Albania  2014    10700.522802               60.10
# 34              Algeria  2014    13549.025150               18.09
# 56               Angola  2014     6813.052106               21.26
# 76  Antigua and Barbuda  2014    20820.551057               64.00

# %%
##highest percentage of country of GDP and internet users in 2014
df_2014.loc[df_2014['GDP_Per_Capita'].idxmax()]
# Out:
# Country                Qatar
# Year                    2014
# GDP_Per_Capita        116694
# Internet_Users_Pct     91.49
# Name: 2556, dtype: object

# %%
##highest percentage of country of GDP and internet users in 2009
df_2009.loc[df_2009['GDP_Per_Capita'].idxmax()]
# Out:
# Country                Qatar
# Year                    2009
# GDP_Per_Capita        112526
# Internet_Users_Pct      53.1
# Name: 2561, dtype: object

# %%
##highest percentage of country of GDP and internet users in 2004
df_2004.loc[df_2004['GDP_Per_Capita'].idxmax()]
# Out:
# Country                 Qatar
# Year                     2004
# GDP_Per_Capita         117271
# Internet_Users_Pct    20.7016
# Name: 2566, dtype: object

# %%
##country has the Lowest internet user and gdp per capita in year 2014
df_2014.loc[df_2014['GDP_Per_Capita'].idxmin()]
# Out:
# Country               Mauritania
# Year                        2014
# GDP_Per_Capita           377.909
# Internet_Users_Pct          10.7
# Name: 1983, dtype: object

# %%
##country has the Lowest internet user and gdp per capita in year 2009
df_2009.loc[df_2009['GDP_Per_Capita'].idxmin()]
# Out:
# Country               Mauritania
# Year                        2009
# GDP_Per_Capita           336.749
# Internet_Users_Pct          2.28
# Name: 1988, dtype: object

# %%
##country has the Lowest internet user and gdp per capita in year 2004
df_2004.loc[df_2004['GDP_Per_Capita'].idxmin()]
# Out:
# Country               Mauritania
# Year                        2004
# GDP_Per_Capita           291.842
# Internet_Users_Pct       0.48147
# Name: 1993, dtype: object

# %%
plt.figure(figsize = (10, 8))
sns.set(style="whitegrid")
plt.scatter(df_2004.GDP_Per_Capita,df_2004.Internet_Users_Pct)
plt.xlabel('GDP_Per_Capita')
plt.ylabel('Intenet_Users_Pct')
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.set(style="whitegrid")
plt.scatter(df_2009.GDP_Per_Capita,df_2009.Internet_Users_Pct)
plt.xlabel('GDP_Per_Capita')
plt.ylabel('Intenet_Users_Pct')
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.set(style="whitegrid")
plt.scatter(df_2014.GDP_Per_Capita,df_2014.Internet_Users_Pct)
plt.xlabel('GDP_Per_Capita')
plt.ylabel('Intenet_Users_Pct')
plt.show()

# %%
##Top ten largest country with highest GDP_Per_Capita in 2014
max_df=df_2014.nlargest(10, columns=['GDP_Per_Capita'])
max_df
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2556                 Qatar  2014   116693.507701               91.49
# 1812            Luxembourg  2014    92349.186486               94.67
# 2765             Singapore  2014    81965.361071               82.00
# 1685                Kuwait  2014    72588.486007               78.70
# 2310                Norway  2014    63419.314779               96.30
# 3297  United Arab Emirates  2014    62948.677902               90.40
# 626         Cayman Islands  2014    62929.874528               74.10
# 3017           Switzerland  2014    57218.027926               87.00
# 3343         United States  2014    52080.792568               87.36
# 2670          Saudi Arabia  2014    49731.779296               63.70

# %%
##Top ten country with highest internet_users_pct in 2014
max_df1=df_2014.nlargest(5, columns=['Internet_Users_Pct'])
max_df1
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1395      Iceland  2014    42774.888851               98.16
# 2310       Norway  2014    63419.314779               96.30
# 854       Denmark  2014    45057.074170               95.99
# 1812   Luxembourg  2014    92349.186486               94.67
# 2199  Netherlands  2014    46238.209702               93.17

# %%
##Create a data frame called top_5_internet from the combined data frame that has all three years.
internet_comb_data =internet_gdp.nlargest(15,columns=['Internet_Users_Pct'])
internet_comb_data
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1395               Iceland  2014    42774.888851            98.16000
# 2310                Norway  2014    63419.314779            96.30000
# 854                Denmark  2014    45057.074170            95.99000
# 1812            Luxembourg  2014    92349.186486            94.67000
# 2199           Netherlands  2014    46238.209702            93.17000
# 1400               Iceland  2009    41505.084835            93.00000
# 2992                Sweden  2014    44213.877969            92.52000
# 1067               Finland  2014    39017.537207            92.38000
# 2315                Norway  2009    62698.285355            92.08000
# 3318        United Kingdom  2014    38418.566122            91.61000
# 2556                 Qatar  2014   116693.507701            91.49000
# 2997                Sweden  2009    40905.799578            91.00000
# 228                Bahrain  2014    43847.909052            90.99998
# ...
